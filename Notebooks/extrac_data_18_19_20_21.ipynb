# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
from pathlib import Path
import pandas as pd
import numpy as np
from spotifuncs2 import *

# %%
path = Path("/Users/jaimesastrecrespo/DAFT_1022/Final_project/spotify_App")

# %%
with open(path / "client_s.txt") as f:
    content = f.readlines()
content = [x.strip() for x in content]

client_id = content[0]
client_secret = content[1]
username = content[3]

# %%
scope = "user-library-read user-read-recently-played user-top-read playlist-modify-public playlist-modify-private playlist-read-private playlist-read-collaborative"

redirect_uri = 'http://localhost:7777/callingmoi'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                      client_secret=client_secret)

# %%
sp_m = authenticate(redirect_uri, client_credentials_manager, username, scope, client_id, client_secret)

# %%
play_2018 = sp_m.playlist("spotify:playlist:37i9dQZF1EjlGNlHTUaWxC")

# %%
play_2018_df = create_df_playlist(play_2018, sp = sp_m)
#play_2018_df.to_csv("my_spotify_2018.csv")

# %%
play_2018_df
# Out:
#                                          track_name  \
# 0                                   Fresas con nata
# 1                                              Amén
# 2                                Llórame - Acústico
# 3                                      Nit salvatge
# 4                                          Amorfoda
# ..                                              ...
# 95                                 Do I Wanna Know?
# 96                    Gin and Drugs (feat. Problem)
# 97                               Generación perdida
# 98  Ama, ama, ama y ensancha el alma - Versión 2004
# 99                                    De Mar en Mar
#
#                                       album                track_id  \
# 0                           Fresas con nata  48sq0JdNEbXhQTdAorTzC9
# 1                                Pa'l Coche  1PLxoOKyLKqicE5ErhrzkF
# 2                        Llórame (Acústico)  1eFx4b7oW6VGtxGBz6aTrW
# ...

# %%
# # find artist id to find Genre

# artists_names = []
# for i in play_2018_df['artist']:

#     artists_names.append(i)


# artist_id = sp_m.search(q=artists_names)
# #Extract Artist's id
# artists_all_id = artist_id['tracks']['items'][0]['artists'][0]['id']

# artists_id = []

# for i in  range(len(artist_id)):
#     lista = artist_id['tracks']['items'][i]['artists'][i]['id']
#     artists_id.append(lista)



# artist_popularity = []
# artist_genres = []
# artist_followers = []
# for a_id in play_2018_df.artist_id:
#   artist = sp_m.artist(a_id)
#   artist_popularity.append(artist['popularity'])
#   artist_genres.append(artist['genres'])
#   artist_followers.append(artist['followers']['total'])

# %%
play_2018_df
# Out:
#                                          track_name  \
# 0                                   Fresas con nata
# 1                                              Amén
# 2                                Llórame - Acústico
# 3                                      Nit salvatge
# 4                                          Amorfoda
# ..                                              ...
# 95                                 Do I Wanna Know?
# 96                    Gin and Drugs (feat. Problem)
# 97                               Generación perdida
# 98  Ama, ama, ama y ensancha el alma - Versión 2004
# 99                                    De Mar en Mar
#
#                                       album                track_id  \
# 0                           Fresas con nata  48sq0JdNEbXhQTdAorTzC9
# 1                                Pa'l Coche  1PLxoOKyLKqicE5ErhrzkF
# 2                        Llórame (Acústico)  1eFx4b7oW6VGtxGBz6aTrW
# ...

# %%
play_2019 = sp_m.playlist("spotify:playlist:37i9dQZF1EtdfiLotZtf3K")
play_2019_df = create_df_playlist(play_2019, sp = sp_m)
play_2019_df.to_csv("my_spotify_2019.csv")

# %%
play_2020 = sp_m.playlist("spotify:playlist:37i9dQZF1ELXwPxY6XKPiF")
play_2020_df = create_df_playlist(play_2020, sp = sp_m)
play_2020_df.to_csv("my_spotify_2020.csv")

# %%
playlist_link = "https://open.spotify.com/user/spotify/playlist/37i9dQZF1EUMDoJuT8yJsl?si=uqkvsPDQRiuYLzGdXiG3mg"

playlist_2021_URI = playlist_link.split("/")[-1].split("?")[0]
playlist_2021_URI
# Out:
# '37i9dQZF1EUMDoJuT8yJsl'

# %%
play_2021 = sp_m.playlist("spotify:playlist:37i9dQZF1EUMDoJuT8yJsl")
play_2021_df = create_df_playlist(play_2021, sp = sp_m)
play_2021_df.to_csv("my_spotify_2021.csv")

# %%
list_df = [play_2019_df, play_2020_df, play_2018_df, play_2021_df]

total_df = pd.concat(list_df,ignore_index=True  )

# %%
# To display the whole viz of columns and/or rows

#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)

duplicate = total_df[total_df.duplicated(['track_id'])]
duplicatesx2 = duplicate[duplicate.duplicated(['track_id'])] 
# I need to find duplicates twice because it showed some inconsistency. It was showing songs ducplicates when actually it was not duplicate.

# %%
total_df.drop(index= 228, inplace= True)

# %%
total_df.duplicated().sum()
#Oh! we still have duplicates, but we are not going to drop that rows. As you can see below, they're different songs so we want to keep them.
# Out:
# 10

# %%
total_df.shape
# Out:
# (399, 17)

# %%
duplicate3 = total_df[total_df.duplicated(['track_id'])]

# %%
duplicate3
# Out:
#                            track_name                              album  \
# 163         Lo Que en Silencio Guardo    Recopilatorio de Temas Inéditos
# 173                         Carretera                          Carretera
# 205                          Ermitaño  Astola & Raton: El Hombre Caracol
# 211                         Desahucio                        Cara y cruz
# 225                    Ese cosquilleo                        Cara y cruz
# 239          Cojo el saco y me retiro                         Rockallano
# 241                        Cicatrices                         Cicatrices
# 249  A veces se me pasa, a veces paso                        Cara y cruz
# 279                  Voy a Celebrarlo                 Si uno no se rinde
# 325                           Mi Casa                         Pa'l Coche
#
#                    track_id              artist  duration  popularity  \
# 163  5ZSHDuhxImgtzSglqEPWJ3                Kaze    165173          50
# ...
